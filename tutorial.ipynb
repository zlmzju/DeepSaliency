# %%
from deepSal import *

# %%
#init caffe net, model path, gpu device_no (-1 means CPU)
net=initNet('./model',device_no=0)

# %%
#process the image to get saliency map
filename='./images/input.jpg'
salmap=processImage(net,filename)

# %% [markdown]
# # Show the input image and output saliency map

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.subplot(1,2,1);plt.imshow(caffe.io.load_image(filename))
plt.subplot(1,2,2);plt.imshow(salmap,cmap='gray')
